# %%
import matplotlib.pyplot as plt
import pandas as pd

# %%
data = pd.read_csv('pi_performance.txt', sep=",", header=None)
#data = data.reset_index(inplace=True)
data = data.set_index(0)
data.columns = ['T.ejecucion']
data.index.rename('Tipo', inplace=True)
data
#data.columns = ['Tipo', 'T.ejecucion']
#data.rename(index={0: "Tipo", 1: "T.ejecucion"})

#columns = ["Secuencial", "MPI", "Parallel", "Priv+crit", "WS", "WS+red", "MPI+OpenMP"]
#df = pd.DataFrame(data)
# Out:
#             T.ejecucion
# Tipo
# Secuencial        0.290
# MPI               0.284
# Parallel          0.043
# Priv+crit         0.505
# WS                0.473
# WS+red            0.042
# MPI+OpenMP        0.283

# %%
ax = data.plot.bar(rot=12, color='red')

# %%
tejec = [44.073,51.829,26.466,30.9394,17.213,19.984,17.690,13.913,23.946,12.783,80.339]
index1 = ['mpi(2)', 'scoop(2)',
         'mpi(4)', 'scoop(4)', 'mpi(8)','scoop(8)','mpi(16)','scoop(16)','mpi(32)','scoop(32)','scoop(120)']
df = pd.DataFrame({'T.ejecucion (s)': tejec}, index=index)
ax = df.plot.bar(rot=25, color='orange')

# %%
speedUp = []
for tiempo in tejec:
    speedUp.append(tejec2[0]/tiempo)
    
df = pd.DataFrame({'SpeedUp': speedUp}, index=index1)
ax = df.plot.bar(rot=25, color='pink')

# %%
tejec2 = [591,80.339]
index2 = ['Serie','scoop(120)']
df = pd.DataFrame({'T.ejecucion (s)': tejec2}, index=index2)
ax = df.plot.bar(rot=25, color='orange')

# %%
speedUp2 = []
for tiempo in tejec2:
    speedUp2.append(tejec2[0]/tiempo)

print(speedUp[1])
df = pd.DataFrame({'SpeedUp': speedUp2}, index=index2)
ax = df.plot.bar(rot=25, color='pink')
# Out:
# 11.402882556097937
