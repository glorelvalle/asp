# %%
import matplotlib.pyplot as plt
import pandas as pd

# %%
tejec = [44.073,51.829,26.466,30.9394,17.213,19.984,17.690,13.913,23.946,12.783,80.339]
index = ['MPI(2)', 'SCOOP(2)',
         'MPI(4)', 'SCOOP(4)', 'MPI(8)','SCOOP(8)','MPI(16)','SCOOP(16)','SCOOP(32)','SCOOP(32)','SCOOP(120)']
df = pd.DataFrame({'T.ejecucion (ms)': tejec}, index=index)
ax = df.plot.bar(rot=30, color='orange')

# %%
speedUp = []
for tiempo in tejec:
    speedUp.append(tejec2[0]/tiempo)
    
df = pd.DataFrame({'SpeedUp': speedUp}, index=index)
ax = df.plot.bar(rot=30, color='pink')

# %%
tejec2 = [591,80.339]
index2 = ['Serie','SCOOP(120)']
df = pd.DataFrame({'T.ejecucion (ms)': tejec2}, index=index2)
ax = df.plot.bar(rot=25, color='orange')

# %%
speedUp2 = []
for tiempo in tejec2:
    speedUp2.append(tejec2[0]/tiempo)

print(speedUp[1])
df = pd.DataFrame({'speedup': speedUp2}, index=index2)
ax = df.plot.bar(rot=25, color='pink')
# Out:
# 11.402882556097937
