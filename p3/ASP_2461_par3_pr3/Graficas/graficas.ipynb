# %%
import matplotlib.pyplot as plt
import pandas as pd

# %%
data = pd.read_csv('pi_performance.txt', sep=",", header=None)
#data = data.reset_index(inplace=True)
data = data.set_index(0)
data.columns = ['T.ejecucion']
data.index.rename('Tipo', inplace=True)
data
#data.columns = ['Tipo', 'T.ejecucion']
#data.rename(index={0: "Tipo", 1: "T.ejecucion"})

#columns = ["Secuencial", "MPI", "Parallel", "Priv+crit", "WS", "WS+red", "MPI+OpenMP"]
#df = pd.DataFrame(data)
# Out:
#             T.ejecucion
# Tipo
# Secuencial        0.290
# MPI               0.284
# Parallel          0.043
# Priv+crit         0.505
# WS                0.473
# WS+red            0.042
# MPI+OpenMP        0.283

# %%
ax = data.plot.bar(rot=12, color='red')

# %%
tejec = [22.124, 83.152, 114.429, 82.152, 118.508, 110.252]
index = ['Serie', 'OpenMP(2)', 'MPI(2)',
         'OpenMP(4)', 'MPI(4)', 'Híbrido(4)']
df = pd.DataFrame({'T.ejecucion (ms)': tejec}, index=index)
ax = df.plot.bar(rot=12, color='red')
